# %%
import pandas as pd
import numpy as np

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.chrome.service import Service

# %%
form_url = 'http://ee.kobo.local/x/2eyzRNLp'
form_prefix = '/aCgbxk7xTdP4RgAwqHmSdo/'
radio_inputs = []

# %%
df = pd.read_csv('घर_धर_ववरण_समबनध_परशनवल_-_all_versions_-_English_en_-_2023-03-27-04-29-43.csv')
df
# Out:
#                                  start                               end  \
# 0     2023-01-22 11:14:33.065000+05:45  2023-01-22 12:40:14.650000+05:45
# 1     2023-01-22 12:28:23.760000+05:45  2023-01-22 13:41:40.404000+05:45
# 2     2023-01-23 07:41:27.409000+05:45  2023-01-23 08:30:15.736000+05:45
# 3     2023-01-22 13:25:41.143000+05:45  2023-01-22 14:40:24.775000+05:45
# 4     2023-01-23 08:46:09.963000+05:45  2023-01-23 09:23:06.357000+05:45
# ...                                ...                               ...
# 2483  2023-03-25 16:01:47.134000+05:45  2023-03-25 16:09:25.114000+05:45
# 2484  2023-03-25 16:09:29.113000+05:45  2023-03-25 16:16:58.792000+05:45
# 2485  2023-03-25 16:17:42.955000+05:45  2023-03-25 16:25:38.326000+05:45
# 2486  2023-03-25 16:25:49.864000+05:45  2023-03-25 16:35:02.856000+05:45
# 2487  2023-03-25 16:35:06.953000+05:45  2023-03-25 17:17:00.890000+05:45
#
#                   Full Name Full Name in Block Letter              Photo  \
# 0                सर्जन बि क                SARJAN B K  1674365422453.jpg
# 1                  पदम बुढा                  पदम बुढा  1674369900109.jpg
# 2             जीब बहादुर बम             जीब बहादुर बम  1674439081459.jpg
# 3              धन बहादुर बम              धन बहादुर बम  1674373307452.jpg
# 4                  मदन बुढा                  मदन बुढा                NaN
# ...                     ...                       ...                ...
# 2483         छत्र बहादुर बम            छत्र बहादुर बम  1679739440993.jpg
# 2484           दानबहादुर बम              दानबहादुर बम  1679739890789.jpg
# 2485                गोरे बम                   गोरे बम  1679740387720.jpg
# 2486                गणेश बम                   गणेश बम  1679740875843.jpg
# 2487  लक्ष्मिचन्द न्यौपाने      लक्ष्मिचन्द न्यौपाने   1679741466188.jpg
#
#                                               Photo_URL         बावुको नाम  \
# 0     http://kc.qbitsx.com/media/original?media_file...           परि बि क
# 1     http://kc.qbitsx.com/media/original?media_file...          नैने बुढा
# 2     http://kc.qbitsx.com/media/original?media_file...      भिम बहादुर बम
# 3     http://kc.qbitsx.com/media/original?media_file...  कुष्ण  बहादुर  बम
# 4                                                   NaN          काजि बुढा
# ...                                                 ...                ...
# 2483  http://kc.qbitsx.com/media/original?media_file...              रन बम
# 2484  http://kc.qbitsx.com/media/original?media_file...              रन बम
# 2485  http://kc.qbitsx.com/media/original?media_file...         बिर्जित बम
# 2486  http://kc.qbitsx.com/media/original?media_file...       मानदहादुर बम
# 2487  http://kc.qbitsx.com/media/original?media_file...  काशिराम न्यौपाने
#
#             आमाको नाम   Grandfather's Name Grandmother's Name  ...  \
# 0           कालि बि क         देउसिगे कामि         रिललि कामि  ...
# 1           झिमु बुढा         प्रदिपे बुढा          काली बुढा  ...
# 2         सुबिस्ता बम         दल बहादुर बम         बेलपुरा बम  ...
# 3           पाटकला बम         कण बहादुर बम           सरिना बम  ...
# 4         पाटकला बुढा        पर्दिपे बुढा         लालकला बुढा  ...
# ...               ...                  ...                ...  ...
# 2483        दौउसरा बम             मनसेर बम           सहधरा बम  ...
# 2484         दौउसर बम             मनसुर बम           सहधरा बम  ...
# 2485      मोतिपुरा बम               खरो बम          कल्पना बम  ...
# 2486       रुपसिला बम             जयरुद बम          फटसिला बम  ...
# 2487  साउनी न्यौपाने   श्रिकिष्न न्यौपाने   पार्बता न्यौपाने   ...
#
#      बैँकमा खाता सञ्चालन.1   _id                                 _uuid  \
# 0                      NaN     3  d75d702f-cc81-4778-8ce9-9c92b100d649
# 1                      NaN     5  11d868cb-cfec-48c8-9944-93906f8e9d9b
# 2                      NaN     7  e726a01e-14a2-45da-868c-2c941a519860
# 3                      NaN     8  7b30cc72-4eb1-43ff-9c50-0769f7ca1976
# 4                      NaN     9  9a9effab-76ac-4de0-b9bd-4db8a592dbad
# ...                    ...   ...                                   ...
# 2483                   NaN  2490  0f76d32b-2e4d-4759-9b95-44f3aaf2f187
# 2484                   NaN  2491  2c9dff8e-9db6-4c87-9109-24c8f28cdd7d
# 2485                   NaN  2492  9d1c45c5-7c12-4d53-b116-8545cb02eb25
# 2486                   NaN  2493  5309baa1-f3d6-4896-b2a5-031485bb83c1
# 2487                   NaN  2494  a320d802-db42-4879-8b9d-35211d4d9c49
#
#          _submission_time _validation_status _notes            _status  \
# 0     2023-01-22 06:55:50                NaN    NaN  submitted_via_web
# 1     2023-01-22 07:57:11                NaN    NaN  submitted_via_web
# 2     2023-01-23 03:33:56                NaN    NaN  submitted_via_web
# 3     2023-01-23 03:34:43                NaN    NaN  submitted_via_web
# 4     2023-01-23 03:39:17                NaN    NaN  submitted_via_web
# ...                   ...                ...    ...                ...
# 2483  2023-03-25 11:59:42                NaN    NaN  submitted_via_web
# 2484  2023-03-25 11:59:52                NaN    NaN  submitted_via_web
# 2485  2023-03-25 12:00:08                NaN    NaN  submitted_via_web
# 2486  2023-03-25 12:00:15                NaN    NaN  submitted_via_web
# 2487  2023-03-25 12:03:06                NaN    NaN  submitted_via_web
#
#                     _submitted_by  _tags  _index
# 0     palata-ward5-data_collector    NaN       1
# 1     palata-ward6-data_collector    NaN       2
# 2     palata-ward7_data_collector    NaN       3
# 3     palata-ward7_data_collector    NaN       4
# 4     palata-ward6-data_collector    NaN       5
# ...                           ...    ...     ...
# 2483  palata-ward2-data_collector    NaN    2484
# 2484  palata-ward2-data_collector    NaN    2485
# 2485  palata-ward2-data_collector    NaN    2486
# 2486  palata-ward2-data_collector    NaN    2487
# 2487  palata-ward2-data_collector    NaN    2488
#
# [2488 rows x 231 columns]

# %%
columns = df.columns
print(columns)
# Out:
# Index(['start', 'end', 'Full Name', 'Full Name in Block Letter', 'Photo',
#        'Photo_URL', 'बावुको नाम', 'आमाको नाम', 'Grandfather's Name',
#        'Grandmother's Name',
#        ...
#        'बैँकमा खाता सञ्चालन.1', '_id', '_uuid', '_submission_time',
#        '_validation_status', '_notes', '_status', '_submitted_by', '_tags',
#        '_index'],
#       dtype='object', length=231)

# %%
null_count = df.isna().sum()
for i in range(len(null_count)):
    print(null_count.index[i],":    ", null_count[i])
# Out:
# start :     0
# end :     0
# Full Name :     0
# Full Name in Block Letter :     3
# Photo :     487
# Photo_URL :     487
# बावुको नाम :     73
# आमाको नाम :     122
# Grandfather's Name :     763
# Grandmother's Name :     1062
# Province :     0
# District :     0
# Municipality :     7
# वार्ड न :     1
# घर नम्बर छ कि छैन? :     5
# House Number :     2485
# GPS Location :     369
# _GPS Location_latitude :     369
# _GPS Location_longitude :     369
# _GPS Location_altitude :     369
# _GPS Location_precision :     369
# टोल विकास संस्थामा आवद्ध हो कि हैन? :     16
# आबद्ध टोल विकास संस्था :     2421
# ल्याण्डलाईन फोन छ कि छैन? :     8
# फोन नं. :     2448
# तपाईको जम्मा परिवार संख्या कति छ ? :     0
# ५. तपाईको परिवारमा १ बर्ष भित्र परिवारको सदस्यको मृत्यु भएको छ कि छैन? :     8
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ? :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/सरकारी स्वास्थ्य संस्था :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/निजी स्वास्थ्य संस्था /क्लिनिक :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/औषधि पसल :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/धामी झाँक्री :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/प्राकृतिक चिकित्सा :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/आयुर्वेदिक औषधालय :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/होमियोपेथी :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/अन्य :     15
# ७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ? (अन्य) :     2488
# ८. गत १२ महिनामा तपाईँको परिवारमा गर्भवती महिलाले नियमित रूपमा तालिम प्राप्त स्वास्थ्य कर्मीहरुबाट स्वास्थ्य जाँच गराउनु भयो ? :     50
# ९. यदि गर्भवती महिलाले नियमित रूपमा तालिम प्राप्त स्वास्थ्यकर्मीबाट स्वास्थ्य जाँच नगराएको भए, कारण के हो ? :     364
# १०. गत १२ महिनामा तपाईँको परिवारबाट कसैले जिवित शिशुलाई जन्म दिनु भएको भए कहाँ जन्म दिनु भयो ? :     254
# ११. गत १२ महिनामा तपाईँको परिवारबाट कसैले जिवित शिशुलाई जन्म दिनु भएको भए बच्चा जन्माउँदा कसले सहयोग गरेको थियो ? :     2488
# ११. गत १२ महिनामा तपाईँको परिवारबाट कसैले जिवित शिशुलाई जन्म दिनु भएको भए बच्चा जन्माउँदा कसले सहयोग गरेको थियो ? (अन्य) :     2488
# १२. यदि तालिम प्राप्त स्वास्थ्य कर्मीबाट सहयोग नलिनु भएको भए किन नलिनु भएको हो ? :     358
# १३. गत १२ महिनामा तपाईँको परिवारको कुनै महिला सदस्यको गर्भवती अवस्थामा वा सुत्केरी हुँदा वा सुत्केरी भएको ६ हप्ता भित्र मृत्यु भएको थियो ? :     14
# १४. गत १२ महिनामा तपाईँको परिवारमा कुनै जन्मिएको शिशुको सुत्केरी हुँदा वा सुत्केरी भएको ६ हप्ता भित्र मृत्यु भएको थियो ? :     9
# १५. तपाईँको परिवारमा ५ वर्ष मुनिका केटाकेटीलाई सबै खोपको मात्रा (वि.सि.जी., डि.पि.टी. र दादुरा) दिनु भएको छ ? :     9
# १६. परिवारले कृषि तथा पशुपालन कार्यका लागी जग्गा प्रयोग गरेको छ ? :     8
# परिवार बाहेक अरुको स्वामित्वमा जग्गा छ ? :     1213
# १८. तपाईँले अन्नबाली उत्पादनको लागि जग्गाको व्यवस्थापन कसरी गर्नु भएको छ ? :     32
# <span style="color:red,">१९. तपाईको स्वामित्वमा रहेको जग्गाको विवरण </span> :     2488
# २०. तपाईँले खेती गरिरहनु भएको जमिनमा सिँचाई सुविधा पुगेको छ ? :     3
# २१. सिँचाई के मार्फत गरिएको छ? :     2234
# २२. तपाई बसेको घरको स्वामित्व कस्तो प्रकारको हो? :     26
# २३. बसेको घरको स्वामित्वको प्रकार (अन्य) :     2487
# २५. तपाईको घर भाडामा दिनु भएको छ कि छैन? :     9
# बहालमा लिनेको नाम :     2484
# बहालको प्रयोग :     2484
# बहालको कोठा संख्या :     2481
# बहालको सम्झौता अवधी :     2483
# बहालको मिति :     2487
# बहाल अवधी :     2487
# बहाल रकम :     2485
# २६. तपाईको परिवारको खानेपानीको मुख्य स्रोत के हो ? :     9
# २६. परिवारको खानेपानीको मुख्य स्रोत (अन्य) :     2486
# २७. पिउने पानी पिउनु अघि शुद्धिकरण गर्ने गर्नुहुन्छ ? :     5
# २८. यदि शुद्धिकरण गर्नुहुन्छ भने कुन विधिको प्रयोग गर्नुभएको छ ? :     2423
# २८. शुद्धिकरण विधिको प्रकार (अन्य) :     2488
# २९. तपाईको परिवारले खाना पकाउन प्रयोग गर्ने मुख्य इन्धन कुन हो? :     7
# २९. परिवारले खाना पकाउन प्रयोग गर्ने मुख्य इन्धन (अन्य) :     2487
# ३०. तपाईँको घरमा कस्तो प्रकारको चुल्हो प्रयोग गर्नु हुन्छ? :     23
# ३०. चुल्होको प्रकार (अन्य) :     2488
# ३१. तपाईँको भान्सामा वायु संचार प्रणाली छ कि छैन ? :     11
# ३२. यदि छ भने कुन प्रकारको रहेको छ ? :     2176
# ३३. तपाईको परिवारले प्रयोग गर्ने बत्तीको मुख्य स्रोत के हो ? :     6
# ३३. बत्तीको मुख्य स्रोत (अन्य) :     2422
# ३४. वत्ति वाल्न विजुलीको प्रयोग गर्नुभएको छ भने, आफ्नै घरमा विजुलीको मिटर जडान भएको छ ? :     6
# ३५. यदि वत्ति वाल्न विजुलीको प्रयोग गर्नुभएको छैन भने किन प्रयोग नगर्नु भएको हो ? :     124
# ३६. तपाईको परिवारले प्रयोग गर्ने शौचालय कस्तो प्रकारको छ ? :     8
# घर, आँगन, शौचालयवाट निष्कृति फोहोरमैलालाई व्यवस्थित गर्ने घरधुरी :     6
# कृषि आय :     1340
# ब्यापार आय :     1392
# उद्योग आय :     1898
# जागीर आय :     1705
# बैदेशिक रोजगारी (विप्रेषण) आय :     1759
# भाडा (बहाल) आय :     1921
# उद्यम आय :     1926
# अन्य आय :     1910
# _version :     0
# खाना वार्षिक खर्च :     334
# शिक्षा खर्च :     665
# स्वास्थ्य खर्च :     607
# कर तथा सेवा शुल्क भुक्तानी खर्च :     1783
# मनोरञ्जन तथा भ्रमण खर्च :     1560
# सामाजिक कार्य खर्च :     1601
# दान खर्च :     1535
# अन्य खर्च :     1750
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ? :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/रेडियो :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/टेलिभिजन :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/टेलिफोन (ल्याण्डलाईन) :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/साधारण मोबाईल फोन :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/स्मार्ट फोन :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/ट्याबलेट :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/कम्प्यूटर :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/ल्यापटप :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/इन्टरनेट :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/मोटरसाइकल/स्कुटर :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/मोटर/कार :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/रेफ्रिजरेटर :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/वासिङ्ग मेशिन :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/एयर कण्डिसनर :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/अन्य सवारी/ढुवानीको साधन(ट्रक, बस, मिनी वस, आदि) :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/ट्याक्टर :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/वाटर फिल्टर :     77
# ४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/विद्युतीय पंखा :     77
# इण्टरनेट सेवा उपलव्ध हुन नसके घर :     25
# मोवाइल फोन प्रयोगकता संख्या :     350
# ४४. परिवारले कुनै चौपाया तथा पशुपंक्षी पालेको छ ? :     12
# ४५. चौपाया तथा पशुपंक्षीहरुको विवरण दिनुहोस :     2488
# गाइगोरु /बाच्छाबाच्छी :     609
# संख्या :     691
# दुध उत्पादन :     1897
# अन्य :     2176
# बिक्रीबाट बार्षिक आम्दानी :     2049
# राँगाभैसी/पाडापाडी :     620
# संख्या.1 :     1503
# दुध उत्पादन.1 :     2140
# मासु उत्पादन :     2260
# हाड/छाला :     2265
# अन्य.1 :     2331
# बिक्रीबाट बार्षिक आम्दानी.1 :     2249
# बाख्रा/भेडा, खसी/बोका, सुँगुर/वंगुर :     620
# संख्या.2 :     1676
# दुध उत्पादन.2 :     2358
# उन :     2309
# मासु उत्पादन.1 :     2292
# अन्य.2 :     2405
# बिक्रीबाट बार्षिक आम्दानी.2 :     2265
# कुखुरा/हाँस :     617
# संख्या.3 :     2115
# मासु उत्पादन.2 :     2341
# अण्डा उत्पादन :     2371
# अन्य.3 :     2440
# बिक्रीबाट बार्षिक आम्दानी.3 :     2386
# अस्ट्रिच :     19
# संख्या.4 :     2487
# मासु उत्पादन.3 :     2487
# अण्डा उत्पादन.1 :     2487
# अन्य.4 :     2488
# बिक्रीबाट बार्षिक आम्दानी.4 :     2487
# कालिज (फ्रेन्च/घर पालुवा) :     16
# संख्या.5 :     2474
# मासु उत्पादन.4 :     2479
# अण्डा उत्पादन.2 :     2481
# अन्य.5 :     2487
# बिक्रीबाट बार्षिक आम्दानी.5 :     2479
# तपाइको परिवारमा माछापालन गरिएको छ ? :     13
# माछापालन पोखरी संख्या :     2486
# माछापालन पोखरीको क्षेत्रफल :     2488
# माछापालन बार्षिक उत्पादन :     2488
# तपाइको परिवारमा मौरीपालन गरिएको छ ? :     17
# मौरी घार संख्या :     2245
# बार्षिक मह उत्पादन :     2300
# तपाइको परिवारमा रेशमपालन गरिएको छ ? :     17
# रेशमखेती कोयो संख्या :     2487
# रेशमखेती उत्पादन :     2487
# स्वास्थ्य चौकी (हेल्थ पोष्ट) रहेको स्थान :     39
# स्वास्थ्य चौकी (हेल्थ पोष्ट) पुग्न लाग्ने समय :     36
# स्वास्थ्य चौकी (हेल्थ पोष्ट) पुग्ने माध्यम :     15
# अस्पताल रहेको स्थान :     380
# अस्पताल पुग्न लाग्ने समय :     242
# अस्पताल पुग्ने माध्यम :     58
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ? :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/नदी वा खोल्सामा :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/सडक छेउमा :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/फोहर थुपार्ने ठाउँमा :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/आफ्नै घर कम्पाउण्ड भित्र :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/कम्पोष्ट मल बनाउने :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/सार्वजनिक स्थलमा :     17
# ४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/खासै निश्चित छैन :     17
# ५०. तपाईँको घर सम्म कस्तो सतह ढलको व्यवस्था छ ? :     12
# ५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ? :     2488
# ५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/नदी वा खोल्सामा :     2488
# ५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/सडकमा :     2488
# ५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/आफ्नै घर कम्पाउण्ड भित्र खनेको खाल्डोमा :     2488
# ५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/करेसाबारीमा :     2488
# ५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/अन्य :     2488
# ५२. तपाईँको टोलमा सार्वजनिक विकास निर्माण सम्वन्धी कार्यको लागतमा समुदायको सहभागीता कति सम्म हुनसक्छ ? :     24
# ५३. तपाईको परिवारमा महिला सदस्य कुनै सङ्घ/संस्थामा संलग्न भएका छन् ? :     8
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ? :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/बाढी :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/पहिरो :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/आगजनी :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/महामारी :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/हावाहुरी :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/चट्याङ्ग :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/नदी कटान :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/खडेरी :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/शीत लहर :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/भुकम्प :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/असिना :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/अन्य :     6
# ५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/प्रकोपको खतरा छैन :     6
# ५६. वितेको एक वर्षभित्र कुनै प्रकोपबाट तपाइँको परिवार पिडीत भयो ? :     8
# घरव्यवहारसम्बन्धी विषयमा निर्णय :     10
# घरायसी काममा संलग्न :     4
# बैँकमा खाता सञ्चालन :     4
# विद्यालय व्यवस्थापन समितिमा सहभागिता :     12
# उद्योग व्यापारमा सहभागिता :     17
# ५९. तपाई पालिकामा करदाताको रुपमा दर्ता हुनुभएको छ कि छैन ? :     9
# ६०. करदाताको रुपमा दर्ता हुनुभएको छ भने करदाता संकेत उल्लेख गर्नुहोस् :     2488
# औंठा छाप (बायाँ) :     376
# औंठा छाप (बायाँ)_URL :     376
# औंठा छाप (दायाँ) :     392
# औंठा छाप (दायाँ)_URL :     392
# __version__ :     0
# _version_ :     0
# _version__001 :     0
# _version__002 :     0
# _version__003 :     0
# _version__004 :     0
# बैँकमा खाता सञ्चालन.1 :     2488
# _id :     0
# _uuid :     0
# _submission_time :     0
# _validation_status :     2488
# _notes :     2488
# _status :     0
# _submitted_by :     0
# _tags :     2488
# _index :     0

# %%
null_count.sum()
# Out:
# 210874

# %%
users = df['_submitted_by'].unique()
users
# Out:
# array(['palata-ward5-data_collector', 'palata-ward6-data_collector',
#        'palata-ward7_data_collector', 'palata-ward9-data_collector',
#        'palata-ward1-data_collector', 'palata-ward4-data_collector',
#        'palata-ward2-data_collector', 'palata-ward3-data_collector',
#        'palata-ward8_data_collector'], dtype=object)

# %%
print(df['Province'].unique())
print(df['District'].unique())
print(df['Municipality'].unique())
# Out:
# ['Karnali Province']
# ['Kalikot' 'Jajarkot']
# ['Palata Rural Municipality' nan]

# %%
jajarkot_rows = df[df['District'] == 'Jajarkot']
jajarkot_rows
# Out:
#                                  start                               end  \
# 1940  2023-02-15 08:00:10.026000+05:45  2023-02-15 08:13:05.523000+05:45
#
#          Full Name Full Name in Block Letter              Photo  \
# 1940  सूचना महतारा          SUCHANA MAHATARA  1676427358754.jpg
#
#                                               Photo_URL   बावुको नाम  \
# 1940  http://kc.qbitsx.com/media/original?media_file...  भर्दे बुढा
#
#          आमाको नाम Grandfather's Name Grandmother's Name  ...  \
# 1940  जान्की बुढा          सिङग बुढा                 NaN  ...
#
#      बैँकमा खाता सञ्चालन.1   _id                                 _uuid  \
# 1940                   NaN  1947  987c4249-1fec-48d2-8137-27a9bef30176
#
#          _submission_time _validation_status _notes            _status  \
# 1940  2023-03-06 01:23:20                NaN    NaN  submitted_via_web
#
#                     _submitted_by  _tags  _index
# 1940  palata-ward4-data_collector    NaN    1941
#
# [1 rows x 231 columns]

# %%
# filter by user
def filter_data_by_user(user, data=df):
    data_user_mask = data['_submitted_by'] == user
    final_data = data[data_user_mask]
    return final_data

# %%
data_user = filter_data_by_user('palata-ward3-data_collector')
data_user
# Out:
#                                  start                               end  \
# 377   2023-01-25 08:14:05.347000+05:45  2023-01-28 08:38:09.992000+05:45
# 378   2023-01-26 08:21:16.341000+05:45  2023-01-26 09:30:34.616000+05:45
# 379   2023-01-26 09:42:00.003000+05:45  2023-01-26 10:34:31.348000+05:45
# 380   2023-01-26 11:41:50.848000+05:45  2023-01-26 12:31:21.053000+05:45
# 381   2023-01-26 12:51:50.978000+05:45  2023-01-26 13:21:56.523000+05:45
# ...                                ...                               ...
# 2101  2023-03-15 09:40:39.303000+05:45  2023-03-15 10:07:27.565000+05:45
# 2102  2023-03-15 10:08:16.715000+05:45  2023-03-15 10:31:09.785000+05:45
# 2103  2023-03-16 07:38:01.219000+05:45  2023-03-16 08:01:43.031000+05:45
# 2104  2023-03-16 08:02:01.172000+05:45  2023-03-16 08:38:31.619000+05:45
# 2105  2023-03-16 08:39:41.897000+05:45  2023-03-16 09:06:13.754000+05:45
#
#                Full Name Full Name in Block Letter              Photo  \
# 377         कुमेर रोकाया              Kumer rokaya  1674613818576.jpg
# 378      हरिकृष्ण रोकाया        Harikrishna rokaya  1674701222953.jpg
# 379          दिप रोकाया                Dipa rokaya  1674705485698.jpg
# 380          प्रभुजन बम              Parbhujan bam  1674712790586.jpg
# 381     दुर्गा सिंह (बम)         Durga singh (bam)  1674716884342.jpg
# ...                  ...                       ...                ...
# 2101             अंग बम                   Anga bam  1678852790914.jpg
# 2102       दुर्ग रोकाया               Durga rokaya  1678854284829.jpg
# 2103           जैमल कामी              Jaimal kami   1678931615154.jpg
# 2104  मिम बहादुर रोकाया         Mim bahadur rokaya  1678933067489.jpg
# 2105         अंग रोकाया                Anga rokaya  1678935342356.jpg
#
#                                               Photo_URL       बावुको नाम  \
# 377   http://kc.qbitsx.com/media/original?media_file...    प्रदिप रोकाया
# 378   http://kc.qbitsx.com/media/original?media_file...   रूपचन्द रोकाया
# 379   http://kc.qbitsx.com/media/original?media_file...  रुपचन्द रोकाया
# 380   http://kc.qbitsx.com/media/original?media_file...     रामबहादुर बम
# 381   http://kc.qbitsx.com/media/original?media_file...      धनमान सिंह
# ...                                                 ...              ...
# 2101  http://kc.qbitsx.com/media/original?media_file...   कालि बहादुर बम
# 2102  http://kc.qbitsx.com/media/original?media_file...    रणविर रोकाया
# 2103  http://kc.qbitsx.com/media/original?media_file...     मानबिरे कामी
# 2104  http://kc.qbitsx.com/media/original?media_file...      देउ रोकाया
# 2105  http://kc.qbitsx.com/media/original?media_file...    रनजित रोकाया
#
#             आमाको नाम Grandfather's Name Grandmother's Name  ...  \
# 377   चन्दरुपा रोकाया     रुपचन्द रोकाया       र्सपा रोकाया  ...
# 378      सर्पा रोकाया      देऊराम रोकाया                ×××  ...
# 379      र्सपा रोकाया      देउराम रोकाया                ×××  ...
# 380        सुनकेशा बम         परेउलाल बम         जैपुरा बम   ...
# 381       रामसिता बम        पन्धमल सिंह       राईकोशा सिंह   ...
# ...               ...                ...                ...  ...
# 2101      राजपुरा बम          मानसिहं बम            दुधा बम  ...
# 2102      छना रोकाया        कालू रोकाया          अना रोकाया  ...
# 2103         मना कामी       देउजिते कामी       बेलकोशा कामी  ...
# 2104    धनरूपा रोकाया        परे रोकाया          अना रोकाया  ...
# 2105    सपुरा रोकाया            सुन्दरे     खम्मेनि रोकाया   ...
#
#      बैँकमा खाता सञ्चालन.1   _id                                 _uuid  \
# 377                    NaN   384  83d30acb-6784-4883-bd8a-5cd239f859fc
# 378                    NaN   385  a365017d-d183-45e7-bd04-ae5c1b6dc97e
# 379                    NaN   386  6d83b6eb-704c-475c-bf2a-7746185dea26
# 380                    NaN   387  c23a24c8-1940-4699-9ffc-42e1708cab57
# 381                    NaN   388  7379f353-324c-4417-96ac-65a360e71ee7
# ...                    ...   ...                                   ...
# 2101                   NaN  2108  b0e42f1b-61b3-4c29-8f67-0e6633597b5a
# 2102                   NaN  2109  641be8ca-fa33-490f-999c-2038182221d5
# 2103                   NaN  2110  1b58e791-1f1f-406a-be26-9627e07a565f
# 2104                   NaN  2111  abd4da35-1236-4988-a7c6-5b7ae75e54ff
# 2105                   NaN  2112  ba9136c5-9043-4375-8d54-3a5acba1c2cc
#
#          _submission_time _validation_status _notes            _status  \
# 377   2023-01-30 12:49:24                NaN    NaN  submitted_via_web
# 378   2023-01-30 12:50:03                NaN    NaN  submitted_via_web
# 379   2023-01-30 12:50:39                NaN    NaN  submitted_via_web
# 380   2023-01-30 12:52:11                NaN    NaN  submitted_via_web
# 381   2023-01-30 12:52:45                NaN    NaN  submitted_via_web
# ...                   ...                ...    ...                ...
# 2101  2023-03-16 15:46:31                NaN    NaN  submitted_via_web
# 2102  2023-03-16 15:46:42                NaN    NaN  submitted_via_web
# 2103  2023-03-16 15:46:49                NaN    NaN  submitted_via_web
# 2104  2023-03-16 15:46:54                NaN    NaN  submitted_via_web
# 2105  2023-03-16 15:46:58                NaN    NaN  submitted_via_web
#
#                     _submitted_by  _tags  _index
# 377   palata-ward3-data_collector    NaN     378
# 378   palata-ward3-data_collector    NaN     379
# 379   palata-ward3-data_collector    NaN     380
# 380   palata-ward3-data_collector    NaN     381
# 381   palata-ward3-data_collector    NaN     382
# ...                           ...    ...     ...
# 2101  palata-ward3-data_collector    NaN    2102
# 2102  palata-ward3-data_collector    NaN    2103
# 2103  palata-ward3-data_collector    NaN    2104
# 2104  palata-ward3-data_collector    NaN    2105
# 2105  palata-ward3-data_collector    NaN    2106
#
# [355 rows x 231 columns]

# %%
s = Service("drivers/chromedriver_linux64/chromedriver") # add the path of the driver
driver = webdriver.Chrome(service=s)

# %%
# click on show more btn
def join_with(data):
    final_join = []
    for c in data:
        name = c.split()
        final_join.append("_".join(name))
    return final_join
        
def get_url(url):
    driver.get(url)
    time.sleep(5)

def show_more_btn():
    show_more = driver.find_element(By.CLASS_NAME, 'Buttons__Button-sc-19xdot-1')
    show_more.click()

def to_bs4_object(html_page):
    soup = BeautifulSoup(html_page, "html.parser")
    return soup

# Return the current url html code
def get_page_source():
    result = driver.page_source
    soup = to_bs4_object(result)
    return soup

def submit_form():
    submit = driver.find_element(By.ID, 'submit-form')
    submit.click()

def fill_form(form_name, data, prefix=form_prefix):
    # fill the form
    input = driver.find_element(By.NAME, prefix + form_name)
    input.clear()
    input.send_keys(data)

def click_radio_btn(form_name):
    radio_btn = driver.find_element(By.XP, form_name)
    radio_btn.click()

def select_option_value(form_name, data):
    select = Select(driver.find_element(By.NAME, form_name))
    select.select_by_value(data)

def select_dropdown(form_name, data):
    # select the dropdown
    select = Select(driver.find_element(By.NAME, form_name))
    select.select_by_visible_text(data)
    

def click_btn(value):
    btn = driver.find_element(By.CLASS_NAME, value)
    btn.click()
    
def click_btns_xpath(xpath, radio_xpath):
    time.sleep(1)
    btn = driver.find_element(By.XPATH, xpath)
    btn.click()
    time.sleep(1)
    radio_btn = driver.find_element(By.XPATH, radio_xpath)
    radio_btn.click()
    time.sleep(1)

# %%
get_url(form_url)

# %%
# fill_form(form_prefix + 'Full_Name', 'Nichal Dahal')

# %%
# submit_form()

# %%
# click_btns_xpath('//button[normalize-space()="none selected"]')

# %%
# for i in range(len(df)):
#     print(dfi)

# %%
text_columns = ["Full Name",
                "Full Name in Block Letter",
                "बावुको नाम",
                "आमाको नाम",
                "Grandfather's Name",
                "Grandmother's Name",
                "वार्ड न",
                "_GPS Location_latitude",
                "_GPS Location_longitude",
                "_GPS Location_altitude",
                "_GPS Location_precision",
                "तपाईको जम्मा परिवार संख्या कति छ ?",
                "परिवार बाहेक अरुको स्वामित्वमा जग्गा छ ?",
                "१८. तपाईँले अन्नबाली उत्पादनको लागि जग्गाको व्यवस्थापन कसरी गर्नु भएको छ ?",
                "२०. तपाईँले खेती गरिरहनु भएको जमिनमा सिँचाई सुविधा पुगेको छ ?",
                "२१. सिँचाई के मार्फत गरिएको छ?",
                "२२. तपाई बसेको घरको स्वामित्व कस्तो प्रकारको हो?",
                "२३. बसेको घरको स्वामित्वको प्रकार (अन्य)",
                "बहालमा लिनेको नाम",
                "बहालको प्रयोग",
                "बहालको कोठा संख्या",
                "बहालको सम्झौता अवधी",
                "बहालको मिति",
                "बहाल अवधी",
                "बहाल रकम",
                "कृषि आय",
                "ब्यापार आय",
                "उद्योग आय",
                "जागीर आय",
                "बैदेशिक रोजगारी (विप्रेषण) आय",
                "भाडा (बहाल) आय",
                "उद्यम आय",
                "अन्य आय",
                "खाना वार्षिक खर्च",
                "शिक्षा खर्च",
                "स्वास्थ्य खर्च",
                "कर तथा सेवा शुल्क भुक्तानी खर्च",
                "मनोरञ्जन तथा भ्रमण खर्च",
                "सामाजिक कार्य खर्च",
                "दान खर्च",
                "अन्य खर्च",
               ]

# %%
joined_columns = join_with(text_columns)
print(joined_columns)
# Out:
# ['Full_Name', 'Full_Name_in_Block_Letter', 'बावुको_नाम', 'आमाको_नाम', "Grandfather's_Name", "Grandmother's_Name", 'वार्ड_न', '_GPS_Location_latitude', '_GPS_Location_longitude', '_GPS_Location_altitude', '_GPS_Location_precision', 'तपाईको_जम्मा_परिवार_संख्या_कति_छ_?', 'परिवार_बाहेक_अरुको_स्वामित्वमा_जग्गा_छ_?', '१८._तपाईँले_अन्नबाली_उत्पादनको_लागि_जग्गाको_व्यवस्थापन_कसरी_गर्नु_भएको_छ_?', '२०._तपाईँले_खेती_गरिरहनु_भएको_जमिनमा_सिँचाई_सुविधा_पुगेको_छ_?', '२१._सिँचाई_के_मार्फत_गरिएको_छ?', '२२._तपाई_बसेको_घरको_स्वामित्व_कस्तो_प्रकारको_हो?', '२३._बसेको_घरको_स्वामित्वको_प्रकार_(अन्य)', 'बहालमा_लिनेको_नाम', 'बहालको_प्रयोग', 'बहालको_कोठा_संख्या', 'बहालको_सम्झौता_अवधी', 'बहालको_मिति', 'बहाल_अवधी', 'बहाल_रकम', 'कृषि_आय', 'ब्यापार_आय', 'उद्योग_आय', 'जागीर_आय', 'बैदेशिक_रोजगारी_(विप्रेषण)_आय', 'भाडा_(बहाल)_आय', 'उद्यम_आय', 'अन्य_आय', 'खाना_वार्षिक_खर्च', 'शिक्षा_खर्च', 'स्वास्थ्य_खर्च', 'कर_तथा_सेवा_शुल्क_भुक्तानी_खर्च', 'मनोरञ्जन_तथा_भ्रमण_खर्च', 'सामाजिक_कार्य_खर्च', 'दान_खर्च', 'अन्य_खर्च']

# %%
form_input = df[text_columns]
form_input
# Out:
#                   Full Name Full Name in Block Letter         बावुको नाम  \
# 0                सर्जन बि क                SARJAN B K           परि बि क
# 1                  पदम बुढा                  पदम बुढा          नैने बुढा
# 2             जीब बहादुर बम             जीब बहादुर बम      भिम बहादुर बम
# 3              धन बहादुर बम              धन बहादुर बम  कुष्ण  बहादुर  बम
# 4                  मदन बुढा                  मदन बुढा          काजि बुढा
# ...                     ...                       ...                ...
# 2483         छत्र बहादुर बम            छत्र बहादुर बम              रन बम
# 2484           दानबहादुर बम              दानबहादुर बम              रन बम
# 2485                गोरे बम                   गोरे बम         बिर्जित बम
# 2486                गणेश बम                   गणेश बम       मानदहादुर बम
# 2487  लक्ष्मिचन्द न्यौपाने      लक्ष्मिचन्द न्यौपाने   काशिराम न्यौपाने
#
#             आमाको नाम   Grandfather's Name Grandmother's Name  वार्ड न  \
# 0           कालि बि क         देउसिगे कामि         रिललि कामि      5.0
# 1           झिमु बुढा         प्रदिपे बुढा          काली बुढा      6.0
# 2         सुबिस्ता बम         दल बहादुर बम         बेलपुरा बम      7.0
# 3           पाटकला बम         कण बहादुर बम           सरिना बम      7.0
# 4         पाटकला बुढा        पर्दिपे बुढा         लालकला बुढा      6.0
# ...               ...                  ...                ...      ...
# 2483        दौउसरा बम             मनसेर बम           सहधरा बम      2.0
# 2484         दौउसर बम             मनसुर बम           सहधरा बम      2.0
# 2485      मोतिपुरा बम               खरो बम          कल्पना बम      2.0
# 2486       रुपसिला बम             जयरुद बम          फटसिला बम      2.0
# 2487  साउनी न्यौपाने   श्रिकिष्न न्यौपाने   पार्बता न्यौपाने       2.0
#
#       _GPS Location_latitude  _GPS Location_longitude  _GPS Location_altitude  \
# 0                  29.347940                81.815307                  2137.0
# 1                        NaN                      NaN                     NaN
# 2                  29.326596                81.789418                  1199.0
# 3                  29.327158                81.789051                  1259.0
# 4                        NaN                      NaN                     NaN
# ...                      ...                      ...                     ...
# 2483                     NaN                      NaN                     NaN
# 2484                     NaN                      NaN                     NaN
# 2485                     NaN                      NaN                     NaN
# 2486                     NaN                      NaN                     NaN
# 2487                     NaN                      NaN                     NaN
#
#       ...  उद्यम आय  अन्य आय खाना वार्षिक खर्च शिक्षा खर्च स्वास्थ्य खर्च  \
# 0     ...       0.0      0.0           30000.0         0.0            0.0
# 1     ...       NaN   3000.0           50000.0     20000.0        30000.0
# 2     ...       NaN      NaN            6000.0         NaN            NaN
# 3     ...       NaN      NaN            6000.0         NaN            NaN
# 4     ...       NaN      NaN            4000.0     50000.0         1500.0
# ...   ...       ...      ...               ...         ...            ...
# 2483  ...       NaN      NaN           50000.0     60000.0         9000.0
# 2484  ...       NaN      NaN          460000.0     30000.0        50000.0
# 2485  ...       NaN      NaN           30000.0     60000.0        50000.0
# 2486  ...       NaN      NaN           60000.0     80000.0        70000.0
# 2487  ...       NaN      NaN           60000.0     90000.0        50000.0
#
#      कर तथा सेवा शुल्क भुक्तानी खर्च मनोरञ्जन तथा भ्रमण खर्च  \
# 0                                0.0                     0.0
# 1                                NaN                 10000.0
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
# ...                              ...                     ...
# 2483                             NaN                     NaN
# 2484                             NaN                     NaN
# 2485                             NaN                     NaN
# 2486                             NaN                     NaN
# 2487                             NaN                     NaN
#
#      सामाजिक कार्य खर्च दान खर्च अन्य खर्च
# 0               10000.0      0.0       NaN
# 1                6000.0   4000.0    3000.0
# 2                   NaN      NaN       NaN
# 3                   NaN      NaN       NaN
# 4                   NaN      NaN       NaN
# ...                 ...      ...       ...
# 2483                NaN      NaN       NaN
# 2484                NaN      NaN       NaN
# 2485                NaN      NaN       NaN
# 2486                NaN      NaN       NaN
# 2487                NaN      NaN       NaN
#
# [2488 rows x 41 columns]

# %%
# for i in range(len(form_input)):
#     for j in range(len(text_columns)):
#         fill_form(form_prefix + joined_columns[j], form_input[text_columns[j]][i])
#     break

# %%
print(text_columns)
# Out:
# ['Full Name', 'Full Name in Block Letter', 'बावुको नाम', 'आमाको नाम', "Grandfather's Name", "Grandmother's Name", 'वार्ड न', '_GPS Location_latitude', '_GPS Location_longitude', '_GPS Location_altitude', '_GPS Location_precision', 'तपाईको जम्मा परिवार संख्या कति छ ?', 'परिवार बाहेक अरुको स्वामित्वमा जग्गा छ ?', '१८. तपाईँले अन्नबाली उत्पादनको लागि जग्गाको व्यवस्थापन कसरी गर्नु भएको छ ?', '२०. तपाईँले खेती गरिरहनु भएको जमिनमा सिँचाई सुविधा पुगेको छ ?', '२१. सिँचाई के मार्फत गरिएको छ?', '२२. तपाई बसेको घरको स्वामित्व कस्तो प्रकारको हो?', '२३. बसेको घरको स्वामित्वको प्रकार (अन्य)', 'बहालमा लिनेको नाम', 'बहालको प्रयोग', 'बहालको कोठा संख्या', 'बहालको सम्झौता अवधी', 'बहालको मिति', 'बहाल अवधी', 'बहाल रकम', 'कृषि आय', 'ब्यापार आय', 'उद्योग आय', 'जागीर आय', 'बैदेशिक रोजगारी (विप्रेषण) आय', 'भाडा (बहाल) आय', 'उद्यम आय', 'अन्य आय', 'खाना वार्षिक खर्च', 'शिक्षा खर्च', 'स्वास्थ्य खर्च', 'कर तथा सेवा शुल्क भुक्तानी खर्च', 'मनोरञ्जन तथा भ्रमण खर्च', 'सामाजिक कार्य खर्च', 'दान खर्च', 'अन्य खर्च']

# %%
def conver_to_int(num):
    try:
        number = int(num)
    except:
        number = 0
    return number

# %%
for i in columns:
    print('"{}",'.format(i))
# Out:
# "start",
# "end",
# "Full Name",
# "Full Name in Block Letter",
# "Photo",
# "Photo_URL",
# "बावुको नाम",
# "आमाको नाम",
# "Grandfather's Name",
# "Grandmother's Name",
# "Province",
# "District",
# "Municipality",
# "वार्ड न",
# "घर नम्बर छ कि छैन?",
# "House Number",
# "GPS Location",
# "_GPS Location_latitude",
# "_GPS Location_longitude",
# "_GPS Location_altitude",
# "_GPS Location_precision",
# "टोल विकास संस्थामा आवद्ध हो कि हैन?",
# "आबद्ध टोल विकास संस्था",
# "ल्याण्डलाईन फोन छ कि छैन?",
# "फोन नं.",
# "तपाईको जम्मा परिवार संख्या कति छ ?",
# "५. तपाईको परिवारमा १ बर्ष भित्र परिवारको सदस्यको मृत्यु भएको छ कि छैन?",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/सरकारी स्वास्थ्य संस्था",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/निजी स्वास्थ्य संस्था /क्लिनिक",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/औषधि पसल",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/धामी झाँक्री",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/प्राकृतिक चिकित्सा",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/आयुर्वेदिक औषधालय",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/होमियोपेथी",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ?/अन्य",
# "७. तपाईँ वा तपाईँको परिवारका सदस्यहरु बिरामी हुँदा प्राय: उपचारको लागि कहाँ जानु हुन्छ ? (अन्य)",
# "८. गत १२ महिनामा तपाईँको परिवारमा गर्भवती महिलाले नियमित रूपमा तालिम प्राप्त स्वास्थ्य कर्मीहरुबाट स्वास्थ्य जाँच गराउनु भयो ?",
# "९. यदि गर्भवती महिलाले नियमित रूपमा तालिम प्राप्त स्वास्थ्यकर्मीबाट स्वास्थ्य जाँच नगराएको भए, कारण के हो ?",
# "१०. गत १२ महिनामा तपाईँको परिवारबाट कसैले जिवित शिशुलाई जन्म दिनु भएको भए कहाँ जन्म दिनु भयो ?",
# "११. गत १२ महिनामा तपाईँको परिवारबाट कसैले जिवित शिशुलाई जन्म दिनु भएको भए बच्चा जन्माउँदा कसले सहयोग गरेको थियो ?",
# "११. गत १२ महिनामा तपाईँको परिवारबाट कसैले जिवित शिशुलाई जन्म दिनु भएको भए बच्चा जन्माउँदा कसले सहयोग गरेको थियो ? (अन्य)",
# "१२. यदि तालिम प्राप्त स्वास्थ्य कर्मीबाट सहयोग नलिनु भएको भए किन नलिनु भएको हो ?",
# "१३. गत १२ महिनामा तपाईँको परिवारको कुनै महिला सदस्यको गर्भवती अवस्थामा वा सुत्केरी हुँदा वा सुत्केरी भएको ६ हप्ता भित्र मृत्यु भएको थियो ?",
# "१४. गत १२ महिनामा तपाईँको परिवारमा कुनै जन्मिएको शिशुको सुत्केरी हुँदा वा सुत्केरी भएको ६ हप्ता भित्र मृत्यु भएको थियो ?",
# "१५. तपाईँको परिवारमा ५ वर्ष मुनिका केटाकेटीलाई सबै खोपको मात्रा (वि.सि.जी., डि.पि.टी. र दादुरा) दिनु भएको छ ?",
# "१६. परिवारले कृषि तथा पशुपालन कार्यका लागी जग्गा प्रयोग गरेको छ ?",
# "परिवार बाहेक अरुको स्वामित्वमा जग्गा छ ?",
# "१८. तपाईँले अन्नबाली उत्पादनको लागि जग्गाको व्यवस्थापन कसरी गर्नु भएको छ ?",
# "<span style="color:red,">१९. तपाईको स्वामित्वमा रहेको जग्गाको विवरण </span>",
# "२०. तपाईँले खेती गरिरहनु भएको जमिनमा सिँचाई सुविधा पुगेको छ ?",
# "२१. सिँचाई के मार्फत गरिएको छ?",
# "२२. तपाई बसेको घरको स्वामित्व कस्तो प्रकारको हो?",
# "२३. बसेको घरको स्वामित्वको प्रकार (अन्य)",
# "२५. तपाईको घर भाडामा दिनु भएको छ कि छैन?",
# "बहालमा लिनेको नाम",
# "बहालको प्रयोग",
# "बहालको कोठा संख्या",
# "बहालको सम्झौता अवधी",
# "बहालको मिति",
# "बहाल अवधी",
# "बहाल रकम",
# "२६. तपाईको परिवारको खानेपानीको मुख्य स्रोत के हो ?",
# "२६. परिवारको खानेपानीको मुख्य स्रोत (अन्य)",
# "२७. पिउने पानी पिउनु अघि शुद्धिकरण गर्ने गर्नुहुन्छ ?",
# "२८. यदि शुद्धिकरण गर्नुहुन्छ भने कुन विधिको प्रयोग गर्नुभएको छ ?",
# "२८. शुद्धिकरण विधिको प्रकार (अन्य)",
# "२९. तपाईको परिवारले खाना पकाउन प्रयोग गर्ने मुख्य इन्धन कुन हो?",
# "२९. परिवारले खाना पकाउन प्रयोग गर्ने मुख्य इन्धन (अन्य)",
# "३०. तपाईँको घरमा कस्तो प्रकारको चुल्हो प्रयोग गर्नु हुन्छ?",
# "३०. चुल्होको प्रकार (अन्य)",
# "३१. तपाईँको भान्सामा वायु संचार प्रणाली छ कि छैन ?",
# "३२. यदि छ भने कुन प्रकारको रहेको छ ?",
# "३३. तपाईको परिवारले प्रयोग गर्ने बत्तीको मुख्य स्रोत के हो ?",
# "३३. बत्तीको मुख्य स्रोत (अन्य)",
# "३४. वत्ति वाल्न विजुलीको प्रयोग गर्नुभएको छ भने, आफ्नै घरमा विजुलीको मिटर जडान भएको छ ?",
# "३५. यदि वत्ति वाल्न विजुलीको प्रयोग गर्नुभएको छैन भने किन प्रयोग नगर्नु भएको हो ?",
# "३६. तपाईको परिवारले प्रयोग गर्ने शौचालय कस्तो प्रकारको छ ?",
# "घर, आँगन, शौचालयवाट निष्कृति फोहोरमैलालाई व्यवस्थित गर्ने घरधुरी",
# "कृषि आय",
# "ब्यापार आय",
# "उद्योग आय",
# "जागीर आय",
# "बैदेशिक रोजगारी (विप्रेषण) आय",
# "भाडा (बहाल) आय",
# "उद्यम आय",
# "अन्य आय",
# "_version",
# "खाना वार्षिक खर्च",
# "शिक्षा खर्च",
# "स्वास्थ्य खर्च",
# "कर तथा सेवा शुल्क भुक्तानी खर्च",
# "मनोरञ्जन तथा भ्रमण खर्च",
# "सामाजिक कार्य खर्च",
# "दान खर्च",
# "अन्य खर्च",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/रेडियो",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/टेलिभिजन",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/टेलिफोन (ल्याण्डलाईन)",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/साधारण मोबाईल फोन",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/स्मार्ट फोन",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/ट्याबलेट",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/कम्प्यूटर",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/ल्यापटप",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/इन्टरनेट",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/मोटरसाइकल/स्कुटर",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/मोटर/कार",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/रेफ्रिजरेटर",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/वासिङ्ग मेशिन",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/एयर कण्डिसनर",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/अन्य सवारी/ढुवानीको साधन(ट्रक, बस, मिनी वस, आदि)",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/ट्याक्टर",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/वाटर फिल्टर",
# "४२. निम्न कुन कुन सुविधाहरु परिवारले उपभोग गरेको छ ?/विद्युतीय पंखा",
# "इण्टरनेट सेवा उपलव्ध हुन नसके घर",
# "मोवाइल फोन प्रयोगकता संख्या",
# "४४. परिवारले कुनै चौपाया तथा पशुपंक्षी पालेको छ ?",
# "४५. चौपाया तथा पशुपंक्षीहरुको विवरण दिनुहोस",
# "गाइगोरु /बाच्छाबाच्छी",
# "संख्या",
# "दुध उत्पादन",
# "अन्य",
# "बिक्रीबाट बार्षिक आम्दानी",
# "राँगाभैसी/पाडापाडी",
# "संख्या.1",
# "दुध उत्पादन.1",
# "मासु उत्पादन",
# "हाड/छाला",
# "अन्य.1",
# "बिक्रीबाट बार्षिक आम्दानी.1",
# "बाख्रा/भेडा, खसी/बोका, सुँगुर/वंगुर",
# "संख्या.2",
# "दुध उत्पादन.2",
# "उन",
# "मासु उत्पादन.1",
# "अन्य.2",
# "बिक्रीबाट बार्षिक आम्दानी.2",
# "कुखुरा/हाँस",
# "संख्या.3",
# "मासु उत्पादन.2",
# "अण्डा उत्पादन",
# "अन्य.3",
# "बिक्रीबाट बार्षिक आम्दानी.3",
# "अस्ट्रिच",
# "संख्या.4",
# "मासु उत्पादन.3",
# "अण्डा उत्पादन.1",
# "अन्य.4",
# "बिक्रीबाट बार्षिक आम्दानी.4",
# "कालिज (फ्रेन्च/घर पालुवा)",
# "संख्या.5",
# "मासु उत्पादन.4",
# "अण्डा उत्पादन.2",
# "अन्य.5",
# "बिक्रीबाट बार्षिक आम्दानी.5",
# "तपाइको परिवारमा माछापालन गरिएको छ ?",
# "माछापालन पोखरी संख्या",
# "माछापालन पोखरीको क्षेत्रफल",
# "माछापालन बार्षिक उत्पादन",
# "तपाइको परिवारमा मौरीपालन गरिएको छ ?",
# "मौरी घार संख्या",
# "बार्षिक मह उत्पादन",
# "तपाइको परिवारमा रेशमपालन गरिएको छ ?",
# "रेशमखेती कोयो संख्या",
# "रेशमखेती उत्पादन",
# "स्वास्थ्य चौकी (हेल्थ पोष्ट) रहेको स्थान",
# "स्वास्थ्य चौकी (हेल्थ पोष्ट) पुग्न लाग्ने समय",
# "स्वास्थ्य चौकी (हेल्थ पोष्ट) पुग्ने माध्यम",
# "अस्पताल रहेको स्थान",
# "अस्पताल पुग्न लाग्ने समय",
# "अस्पताल पुग्ने माध्यम",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/नदी वा खोल्सामा",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/सडक छेउमा",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/फोहर थुपार्ने ठाउँमा",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/आफ्नै घर कम्पाउण्ड भित्र",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/कम्पोष्ट मल बनाउने",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/सार्वजनिक स्थलमा",
# "४९. तपाईँको परिवारले घरबाट निस्कने ठोस फोहरमैला सामान्यतया कहाँ फाल्नुहुन्छ ?/खासै निश्चित छैन",
# "५०. तपाईँको घर सम्म कस्तो सतह ढलको व्यवस्था छ ?",
# "५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?",
# "५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/नदी वा खोल्सामा",
# "५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/सडकमा",
# "५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/आफ्नै घर कम्पाउण्ड भित्र खनेको खाल्डोमा",
# "५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/करेसाबारीमा",
# "५१. यदि तपाईँको घर सम्म सतह ढलको व्यवस्था छैन भने घरबाट निस्कने फोहर पानी सामान्यतया कहाँ फाल्नुहुन्छ ?/अन्य",
# "५२. तपाईँको टोलमा सार्वजनिक विकास निर्माण सम्वन्धी कार्यको लागतमा समुदायको सहभागीता कति सम्म हुनसक्छ ?",
# "५३. तपाईको परिवारमा महिला सदस्य कुनै सङ्घ/संस्थामा संलग्न भएका छन् ?",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/बाढी",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/पहिरो",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/आगजनी",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/महामारी",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/हावाहुरी",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/चट्याङ्ग",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/नदी कटान",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/खडेरी",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/शीत लहर",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/भुकम्प",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/असिना",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/अन्य",
# "५५. तपाईँको घरपरिवारलाई कुन प्राकृतिक प्रकोपको बढी खतरा छ ?/प्रकोपको खतरा छैन",
# "५६. वितेको एक वर्षभित्र कुनै प्रकोपबाट तपाइँको परिवार पिडीत भयो ?",
# "घरव्यवहारसम्बन्धी विषयमा निर्णय",
# "घरायसी काममा संलग्न",
# "बैँकमा खाता सञ्चालन",
# "विद्यालय व्यवस्थापन समितिमा सहभागिता",
# "उद्योग व्यापारमा सहभागिता",
# "५९. तपाई पालिकामा करदाताको रुपमा दर्ता हुनुभएको छ कि छैन ?",
# "६०. करदाताको रुपमा दर्ता हुनुभएको छ भने करदाता संकेत उल्लेख गर्नुहोस्",
# "औंठा छाप (बायाँ)",
# "औंठा छाप (बायाँ)_URL",
# "औंठा छाप (दायाँ)",
# "औंठा छाप (दायाँ)_URL",
# "__version__",
# "_version_",
# "_version__001",
# "_version__002",
# "_version__003",
# "_version__004",
# "बैँकमा खाता सञ्चालन.1",
# "_id",
# "_uuid",
# "_submission_time",
# "_validation_status",
# "_notes",
# "_status",
# "_submitted_by",
# "_tags",
# "_index",

# %%
def click_radio_btn(xpath):
    radio_btn = driver.find_element(By.XPATH, xpath)
    radio_btn.click()

# %%
for i in range(len(df)):
    fill_form('Full_Name', df['Full Name'][i])
    fill_form('Full_Name_in_Block_Letter', df['Full Name in Block Letter'][i])
    fill_form('__006', df['बावुको नाम'][i])
    fill_form('_006_003', df['आमाको नाम'][i])
    fill_form('__007', df["Grandfather's Name"][i])
    fill_form('__008', df["Grandmother's Name"][i])
    click_btns_xpath('//label[10]/div/button', "//label[10]/div/ul/li/a/label/input[@value='6']")
    click_btns_xpath('//label[11]/div/button', "//label[11]/div/ul/li/a/label/input[@value='64']")
    click_btns_xpath('//label[12]/div/button', "//label[12]/div/ul/li/a/label/input[@value='754']")
    fill_form('__114', conver_to_int(df['वार्ड न'][i]))
    if df["घर नम्बर छ कि छैन?"][i] == 'छ':
        click_radio_btn("//input[@value='_'][@name='/aCgbxk7xTdP4RgAwqHmSdo/_']")
        time.sleep(1)
        fill_form('__009', df['House Number'][i])
    else:
        click_radio_btn("//input[@value='__1'][@name='/aCgbxk7xTdP4RgAwqHmSdo/_']")
    fill_form('lat', df['_GPS Location_latitude'][i], prefix='')
    fill_form('long', df['_GPS Location_longitude'][i], prefix='')
    fill_form('alt', df['_GPS Location_altitude'][i], prefix='')
    fill_form('acc', df['_GPS Location_precision'][i], prefix='')
    if df["टोल विकास संस्थामा आवद्ध हो कि हैन?"][i] == 'हो':
        click_radio_btn("//input[@value='_'][@name='/aCgbxk7xTdP4RgAwqHmSdo/__001']")
        time.sleep(2)
        fill_form('__011', df['आबद्ध टोल विकास संस्था'][i])
    else:
        click_radio_btn("//input[@value='__1'][@name='/aCgbxk7xTdP4RgAwqHmSdo/__001']")
    if df["ल्याण्डलाईन फोन छ कि छैन?"][i] == 'छ':
        click_radio_btn("//input[@value='_'][@name='/aCgbxk7xTdP4RgAwqHmSdo/__002']")
        time.sleep(1)
        fill_form('__012', df['फोन नं.'][i])
    else:
        click_radio_btn("//input[@value='__1'][@name='/aCgbxk7xTdP4RgAwqHmSdo/__002']")
    fill_form('__003', conver_to_int(df['तपाईको जम्मा परिवार संख्या कति छ ?'][i]))
    fill_form('group_mz42f71/_014512', conver_to_int(df['कृषि आय'][i]))
    fill_form('group_mz42f71/_12454545', conver_to_int(df['ब्यापार आय'][i]))
    fill_form('group_mz42f71/_52012', conver_to_int(df['उद्योग आय'][i]))
    fill_form('group_mz42f71/_12054', conver_to_int(df['जागीर आय'][i]))
    fill_form('group_mz42f71/_2155878', conver_to_int(df['बैदेशिक रोजगारी (विप्रेषण) आय'][i]))
    fill_form('group_mz42f71/_212544', conver_to_int(df['भाडा (बहाल) आय'][i]))
    fill_form('group_mz42f71/_545121', conver_to_int(df['उद्यम आय'][i]))
    fill_form('group_mz42f71/_45456876754', conver_to_int(df['अन्य आय'][i]))
    fill_form('_020_001', conver_to_int(df['खाना वार्षिक खर्च'][i]))
    fill_form('_021_001', conver_to_int(df['शिक्षा खर्च'][i]))
    fill_form('_022_002', conver_to_int(df['स्वास्थ्य खर्च'][i]))
    fill_form('_023_001', conver_to_int(df['कर तथा सेवा शुल्क भुक्तानी खर्च'][i]))
    fill_form('_024_001', conver_to_int(df['मनोरञ्जन तथा भ्रमण खर्च'][i]))
    fill_form('_025_001', conver_to_int(df['सामाजिक कार्य खर्च'][i]))
    fill_form('_026_001', conver_to_int(df['दान खर्च'][i]))
    fill_form('_027_001', conver_to_int(df['अन्य खर्च'][i]))
    fill_form('__057', conver_to_int(df['मोवाइल फोन प्रयोगकता संख्या'][i]))
    fill_form('__089', df['स्वास्थ्य चौकी (हेल्थ पोष्ट) रहेको स्थान'][i])
    fill_form('__090', conver_to_int(df['स्वास्थ्य चौकी (हेल्थ पोष्ट) पुग्न लाग्ने समय'][i]))
    fill_form('__092', df['अस्पताल रहेको स्थान'][i])
    fill_form('__093', conver_to_int(df['अस्पताल पुग्न लाग्ने समय'][i]))
#     fill_form('', df[''][i])
#     fill_form('', df[''][i])
#     fill_form('', df[''][i])
#     fill_form('', df[''][i])
#     fill_form('', df[''][i])
#     fill_form('', df[''][i])
    break
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[28], line 33
#      31     fill_form('__012', df['फोन नं.'][i])
#      32 else:
# ---> 33     click_radio_btn("//input[@value='__1'][@name='[@name='/aCgbxk7xTdP4RgAwqHmSdo/__001']")
#      34 fill_form('__003', conver_to_int(df['तपाईको जम्मा परिवार संख्या कति छ ?'][i]))
#      35 fill_form('group_mz42f71/_014512', conver_to_int(df['कृषि आय'][i]))
#
# Cell In[27], line 2, in click_radio_btn(xpath)
#       1 def click_radio_btn(xpath):
# ----> 2     radio_btn = driver.find_element(By.XPATH, xpath)
#       3     radio_btn.click()
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# InvalidSelectorException: Message: invalid selector: Unable to locate an element with the xpath expression //input[@value='__1'][@name='[@name='/aCgbxk7xTdP4RgAwqHmSdo/__001'] because of the following error:
# SyntaxError: Failed to execute 'evaluate' on 'Document': The string '//input[@value='__1'][@name='[@name='/aCgbxk7xTdP4RgAwqHmSdo/__001']' is not a valid XPath expression.
#   (Session info: chrome=111.0.5563.110)
# Stacktrace:
# #0 0x564949b35243 <unknown>
# #1 0x5649498f97a6 <unknown>
# #2 0x5649498fcd03 <unknown>
# #3 0x5649498fca72 <unknown>
# #4 0x5649498fcd8c <unknown>
# #5 0x564949936221 <unknown>
# #6 0x564949936761 <unknown>
# #7 0x564949971da4 <unknown>
# #8 0x5649499570ad <unknown>
# #9 0x56494996f932 <unknown>
# #10 0x564949956e53 <unknown>
# #11 0x5649499299ea <unknown>
# #12 0x56494992ab2e <unknown>
# #13 0x564949b89d5e <unknown>
# #14 0x564949b8da80 <unknown>
# #15 0x564949b6f8b0 <unknown>
# #16 0x564949b8eb63 <unknown>
# #17 0x564949b60f75 <unknown>
# #18 0x564949bb1998 <unknown>
# #19 0x564949bb1b27 <unknown>
# #20 0x564949bccc23 <unknown>
# #21 0x7f22bb894b43 <unknown>

# %%
# print(get_page_source())

# %%
# click_btns_xpath('//label[10]/div/button', "//label[10]/div/ul/li/a/label/input[@value='6']")
# click_btns_xpath('//label[11]/div/button', "//label[11]/div/ul/li/a/label/input[@value='64']")
# click_btns_xpath('//label[12]/div/button', "//label[12]/div/ul/li/a/label/input[@value='754']")

# %%
df["ल्याण्डलाईन फोन छ कि छैन?"].unique()
